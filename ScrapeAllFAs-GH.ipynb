# %%
import time
from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait # available since 2.4.0
from selenium.webdriver.support import expected_conditions as EC # available since 2.26.0
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from pywebcopy import save_website
from pywebcopy import WebPage
import pywebcopy
from bs4 import BeautifulSoup
import pandas as pd
pywebcopy.config['bypass_robots'] = True
from datetime import datetime

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# [WDM] - Current google-chrome version is 85.0.4183
# WDM        - INFO     - Current google-chrome version is 85.0.4183
# [WDM] - Get LATEST driver version for 85.0.4183
# WDM        - INFO     - Get LATEST driver version for 85.0.4183
# [WDM] - Driver [C:\Users\mpden\.wdm\drivers\chromedriver\win32\85.0.4183.87\chromedriver.exe] found in cache
# WDM        - INFO     - Driver [C:\Users\mpden\.wdm\drivers\chromedriver\win32\85.0.4183.87\chromedriver.exe] found in cache

# %%
driver = webdriver.Chrome()

driver.get('https://www.espn.com/');
time.sleep(8)

##Open Initial Log In Location
search_box = driver.find_element_by_id('global-user-trigger')
print(search_box)
search_box.click()
time.sleep(2)

##Click on the Log In location
nextbox = driver.find_element_by_xpath("//a[@data-affiliatename='espn']")
print(nextbox)
nextbox.click()

##Switch to iFrame to enter log in credentials
time.sleep(2)
driver.switch_to.frame("disneyid-iframe")
username = driver.find_element_by_xpath("//input[@placeholder='Username or Email Address']")

##Submit Username and Password
time.sleep(2)
username.send_keys('USERNAME')
password = driver.find_element_by_xpath("//input[@placeholder='Password (case sensitive)']")
password.send_keys('PASSWORD')
time.sleep(2)

##Submit credentials
button = driver.find_element_by_xpath("//button[@class='btn btn-primary btn-submit ng-isolate-scope']")
button.click()
driver.page_source

##Open Link Page
time.sleep(8)
search_box = driver.find_element_by_id('global-user-trigger')
search_box.click()

##Selecting Fantasy League
time.sleep(2)
leaguego = driver.find_element_by_partial_link_text('TEAMNAME')
leaguego.click()

#Open Players Tab
time.sleep(2)
leaguego = driver.find_element_by_partial_link_text('Players')
leaguego.click()
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="89826687d145b6017567cda296eceddb", element="a8592337-2296-4ef5-bf12-c2c6b1ad6d8b")>
# <selenium.webdriver.remote.webelement.WebElement (session="89826687d145b6017567cda296eceddb", element="39d4dbd8-f4e9-46d7-ba37-3bffe0cf0164")>

# %%
count = 1
for x in range(17):
    page = driver.page_source
    soup = BeautifulSoup(page, 'html.parser')
    tables = soup.find_all("table")

    table = tables[0]
    tab_data = [[cell.text for cell in row.find_all(["th","td"])]
                            for row in table.find_all("tr")]
    df = pd.DataFrame(tab_data)
    df.columns = df.iloc[1]
    df = df.drop([0,1])
    time.sleep(2)
    leaguego = driver.find_element_by_xpath("//button[@class='Button Button--default Button--icon-noLabel Pagination__Button inline-flex']")
    leaguego.click()
    print(f'loop {count}')
    count = count+1
    df.to_csv(f"...\\df{count}.csv")
    
    #<button class="Button Button--default Button--icon-noLabel Pagination__Button inline-flex" aria-selected="false" aria-label="" data-nav-item="2" role="button"><svg class="icon__svg" viewBox="0 0 24 24"><use xlink:href="#icon__caret__right"></use></svg></button>
# Out:
# loop 1
# loop 2
# loop 3
# loop 4
# loop 5
# loop 6
# loop 7
# loop 8
# loop 9
# loop 10
# loop 11
# loop 12
# loop 13
# loop 14
# loop 15
# loop 16
# loop 17

# %%
import os
import glob

# %%
path = r'...' # use your path
all_files = glob.glob(path + "\\*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

faframe = pd.concat(li, axis=0, ignore_index=True)
print(faframe)
faframe['PullTime'] = datetime.now()
faframe['Week'] = 1
# Out:
#      Unnamed: 0                   Player      type  action     opp  \
# 0             2          Geno SmithSeaQB  WA (Thu)     NaN   @Mia
# 1             3        Chase DanielDetQB  WA (Thu)     NaN     NO
# 2             4     Isaiah McKenzieBufWR  WA (Thu)     NaN    @LV
# 3             5        Xavier JonesLARRB  WA (Thu)     NaN    NYG
# 4             6       Isaiah WrightWshWR  WA (Thu)     NaN    Bal
# ..          ...                      ...       ...     ...     ...
# 845          47          Will GrierCarQB  WA (Thu)     NaN    Ari
# 846          48  Sebastian JanikowskiFAK  WA (Thu)     NaN      --
# 847          49       Freddie SwainSeaWR  WA (Thu)     NaN   @Mia
# 848          50           Brett MaherFAK  WA (Thu)     NaN      --
# 849          51         AJ McCarronHouQB  WA (Thu)     NaN    Min
#
#            STATUS proj SCORE  OPRK  %ST  %ROST  +/-  PRK  FPTS  avg LAST
# 0    Sun 11:00 AM  0.1    --  29th  0.0    0.0  0.0   --    --   --   --
# ...

# %%
faframe
# Out:
#      Unnamed: 0                   Player      type  action     opp  \
# 0             2          Geno SmithSeaQB  WA (Thu)     NaN   @Mia
# 1             3        Chase DanielDetQB  WA (Thu)     NaN     NO
# 2             4     Isaiah McKenzieBufWR  WA (Thu)     NaN    @LV
# 3             5        Xavier JonesLARRB  WA (Thu)     NaN    NYG
# 4             6       Isaiah WrightWshWR  WA (Thu)     NaN    Bal
# ..          ...                      ...       ...     ...     ...
# 845          47          Will GrierCarQB  WA (Thu)     NaN    Ari
# 846          48  Sebastian JanikowskiFAK  WA (Thu)     NaN      --
# 847          49       Freddie SwainSeaWR  WA (Thu)     NaN   @Mia
# 848          50           Brett MaherFAK  WA (Thu)     NaN      --
# 849          51         AJ McCarronHouQB  WA (Thu)     NaN    Min
#
#            STATUS proj SCORE  OPRK  %ST  %ROST  +/-  PRK  FPTS  avg LAST  \
# 0    Sun 11:00 AM  0.1    --  29th  0.0    0.0  0.0   --    --   --   --
# ...

# %%
nflteams = pd.read_csv('...\\teamacc.csv')
fadf = pd.DataFrame(columns = ['Name', 'NFL_Team', 'Pos','Injury_Status', 'Opponent', 'Kickoff', 'Proj', 'Score', 'OPRK', '%Start', "%Owned", "OwnerChange", "PRK", "EstPoints", "Avg", "Last", "TimeUpdated"])

for row,col in faframe.iterrows():
    player = col[1]
    opp = col[4]
    kickoff = col[5]
    proj = col[6]
    score = col[7]
    oprk = col[8]
    percstart = col[9]
    percrost = col[10]
    ownchange = col[11]
    prk = col[12]
    projallseason = col[13]
    avg = col[14]
    last = col[15]
    timeupdated = col[16]
    week = col[17]
    for team, ac in nflteams.iterrows():
        try:
            if len(ac[1])>2 and ("D/ST" not in player) and player[-1] != 'K' and ac[1] in player[-8:]:
                #Replace Team Acronym from Name String
                playpos = player.replace(ac[1], "")
                #Get to Injury status if aparent 
                play = playpos[-3]
                pos = playpos[-2:]
                if play[-1] =='Q':
                    print(f'{playpos[:-3]} and {ac[1]} and Questionable')
                    play = playpos[:-3]
                    inj = "Q"
                    team = ac[1]
                    fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
                else:
                    print(f'{playpos[:-2]} and {ac[1]}')
                    play = playpos[:-2]
                    inj = ""
                    team = ac[1]
                    fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
            elif len(ac[1])<3 and ("D/ST" not in player) and player[-1] != 'K' and ac[1] in player[-8:]:
                #Replace Team Acronym from Name String
                playpos = player.replace(ac[1], "")
                #Get to Injury status if aparent 
                play = playpos[:-3]
                pos = playpos[-2:]
                if play[-1] =='Q':
                    print(f'{playpos[:-3]} and {ac[1]} and Questionable')
                    play = playpos[:-3]
                    inj = "Q"
                    team = ac[1]
                    fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
                else:
                    print(f'{playpos[:-2]} and {ac[1]}')
                    play = playpos[:-2]
                    inj = ""
                    team = ac[1]
                    fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
            elif ac[1] in player[-8:] and player[-1] =="K":
                #Replace Team Acronym from Name String
                playpos = player.replace(ac[1], "")
                #Get to Injury status if aparent 
                pos = playpos[-2]
                pos = "K"
                if pos == "Q":
                    print("Questionable")
                    inj = "Q"
                    team = ac[1]
                    fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
                else:
                    print(f'{playpos[:-1]} and {ac[1]}')
                    play = playpos[:-1]
                    inj = ""
                    team = ac[1]
                    fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
            elif ac[1] in player[-8:] and "D/ST" in player:
                #Replace Team Acronym from Name String
                playpos = player.replace(ac[1], "")
                play = playpos.replace(" D/ST", " ")
                pos = "D/ST"
                print(play)
                team = ac[1]
                fadf = fadf.append({'Name': play, 'NFL_Team': team, 'Pos': pos,'Injury_Status': inj, 'Opponent':opp, "Kickoff": kickoff, 'Proj': proj, 'Score': score, 'OPRK':oprk, '%Start': percstart, "%Owned": percrost, "OwnerChange":ownchange, "PRK": prk, "EstPoints":projallseason , "Avg": avg, "Last": last,  "Week": week, "TimeUpdated": timeupdated},ignore_index=True)
            elif player == "Empty":
                pass
                play = "Empty"
                ac[1] = ""
                pos = None
        except:
            print(player)
# Out:
# Geno Smith and Sea
# Chase Daniel and Det
# Isaiah McKenzie and Buf
# Xavier Jones and LAR
# Isaiah Wright and Wsh
# Jauan Jennings and SF
# Chris Streveler and Ari
# Alex Armah and Car
# Kahale WarringIR and Hou
# Olamide Zaccheaus and Atl
# Senorise PerryIR and Ten
# Brian Hoyer and NE
# DeAndre Carter and Hou
# Andre Roberts and Buf
# Matt Schaub and Atl
# Dontrell Hilliard and Cle
# Alex Erickson and Cin
# Marquez Callaway and NO
# Alec Ingold and LV
# Damion Ratley and NYG
# D'Ernest Johnson and Cle
# Rico Dowdle and Dal
# Marvin Hall and Det
# Ross Dwelley and SF
# Colt McCoy and NYG
# Antonio Callaway and Cle
# Christian Blake and Atl
# KhaDarel Hodge and Cle
# Ryan Finley and Cin
# Michael Crabtree and Ari
# Jaeden Graham and Atl
# C.J. Board and NYG
# Ray-Ray McCloud and Pit
# Tavon AustinIR and SF
# Noah Togiai and Ind
# C.J. Prosise and Hou
# Elijhaa Penny and NYG
# Darren Sproles and Phi
# K.J. Osborn and Min
# Noah Brown and Dal
# Nick Vannett and Den
# ...

# %%
fadf
# Out:
#                 Name NFL_Team Pos Injury_Status Opponent       Kickoff Proj  \
# 0         Geno Smith      Sea  QB                  @Mia   Sun 11:00 AM  0.1
# 1       Chase Daniel      Det  QB                    NO   Sun 11:00 AM  0.1
# 2    Isaiah McKenzie      Buf  WR                   @LV    Sun 2:25 PM  1.5
# 3       Xavier Jones      LAR  RB                   NYG    Sun 2:05 PM  0.0
# 4      Isaiah Wright      Wsh  WR                   Bal   Sun 11:00 AM  2.3
# ..               ...      ...  ..           ...      ...           ...  ...
# 593  Anthony Sherman       KC  RB                    NE    Sun 2:25 PM  0.6
# 594     John Wolford      LAR  QB                   NYG    Sun 2:05 PM  0.1
# 595       Will Grier      Car  QB                   Ari   Sun 11:00 AM  0.0
# 596    Freddie Swain      Sea  WR                  @Mia   Sun 11:00 AM  2.1
# 597      AJ McCarron      Hou  QB                   Min   Sun 11:00 AM  0.1
#
# ...

# %%
eggbakedf.to_csv("...\\combinedfa.csv")
